# %% [markdown]
# # 딥러닝3 : 다중분류

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 2.데이터 준비

# %%
# np.argmax()
a = np.array([[1,2,3],[3,1,2]])
a
# Out:
# array([[1, 2, 3],
#        [3, 1, 2]])

# %%
np.argmax(a, axis = 0)
# Out:
# array([1, 0, 0])

# %%
np.argmax(a, axis = 1)
# Out:
# array([2, 0])

# %%
np.argmax(a)
# Out:
# 2

# %% [markdown]
# ### (1) y 값을 0,1,2로 변환하기
# (sparse_categorical_crossentropy 사용을 위해)

# %%
data['Species'] = data['Species'].map({'setosa':0, 'versicolor':1, 'virginica':2})
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ### (2) 데이터 준비

# %%
target = 'Species'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) 데이터 분할 : train : val

# %%
x.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int64

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.모델링1

# %% [markdown]
# ### (1) 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 4

# %%
# 메모리 정리
clear_session()

# Sequential
model = Sequential( [Input(shape = (nfeatures,)),
                     Dense( 3, activation = 'softmax')] )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 3)                   │              15 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15 (60.00 B)
#  Trainable params: 15 (60.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss= 'sparse_categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 50,
                    validation_split=0.2).history
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 1.0953 - val_loss: 0.9263
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8933 - val_loss: 0.7472
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7670 - val_loss: 0.6175
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6457 - val_loss: 0.5287
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5836 - val_loss: 0.4743
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5243 - val_loss: 0.4227
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4668 - val_loss: 0.3933
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4523 - val_loss: 0.3702
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4188 - val_loss: 0.3489
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4102 - val_loss: 0.3332
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3864 - val_loss: 0.3193
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4019 - val_loss: 0.3079
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3481 - val_loss: 0.2985
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3458 - val_loss: 0.2892
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3382 - val_loss: 0.2821
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3292 - val_loss: 0.2745
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3254 - val_loss: 0.2678
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3183 - val_loss: 0.2607
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3151 - val_loss: 0.2567
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2934 - val_loss: 0.2492
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2880 - val_loss: 0.2444
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2992 - val_loss: 0.2393
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2847 - val_loss: 0.2351
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2821 - val_loss: 0.2329
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2736 - val_loss: 0.2296
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2708 - val_loss: 0.2225
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2676 - val_loss: 0.2193
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2681 - val_loss: 0.2163
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2623 - val_loss: 0.2122
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2662 - val_loss: 0.2085
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2362 - val_loss: 0.2090
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2342 - val_loss: 0.2038
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2379 - val_loss: 0.1995
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2340 - val_loss: 0.1981
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2200 - val_loss: 0.1940
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2228 - val_loss: 0.1910
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2337 - val_loss: 0.1902
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2364 - val_loss: 0.1869
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1995 - val_loss: 0.1835
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2191 - val_loss: 0.1807
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2183 - val_loss: 0.1793
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2189 - val_loss: 0.1762
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2097 - val_loss: 0.1743
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2015 - val_loss: 0.1726
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2227 - val_loss: 0.1702
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1984 - val_loss: 0.1700
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1886 - val_loss: 0.1658
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1992 - val_loss: 0.1636
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1899 - val_loss: 0.1634
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2246 - val_loss: 0.1598

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증
# * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
pred[:5]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# array([[9.7878778e-01, 2.1149548e-02, 6.2799540e-05],
#        [9.5732175e-03, 8.1434727e-01, 1.7607941e-01],
#        [1.1984000e-02, 7.4872041e-01, 2.3929563e-01],
#        [3.1899990e-04, 3.5983518e-01, 6.3984579e-01],
#        [2.9540692e-02, 8.9652026e-01, 7.3938981e-02]], dtype=float32)

# %% [markdown]
# * 행 별로 제일 큰 값을 찾아서 그에 맞게 숫자(0,1,2)로 변환 합시다.

# %%
# 5개 행만 살펴보면
np.argmax(pred[:5], axis = 1)
# Out:
# array([0, 1, 1, 2, 1])

# %%
pred_1 = pred.argmax(axis=1)
pred_1
# Out:
# array([0, 1, 1, 2, 1, 1, 2, 0, 2, 0, 2, 1, 1, 0, 0, 2, 0, 1, 2, 1, 1, 2,
#        2, 0, 1, 1, 1, 0, 2, 1, 1, 1, 0, 0, 0, 1, 2, 0, 1, 2, 1, 1, 0, 1,
#        2])

# %% [markdown]
# * 실제값 y_val은 0,1,2 로 된 1차원 값입니다.

# %%
y_val
# Out:
# 47     0
# 73     1
# 74     1
# 129    2
# 67     1
# 89     1
# 143    2
# 21     0
# 108    2
# 12     0
# 147    2
# 76     1
# 119    2
# 35     0
# 28     0
# 122    2
# 13     0
# 58     1
# 114    2
# 57     1
# 50     1
# 149    2
# 111    2
# 20     0
# 72     1
# 81     1
# 98     1
# 34     0
# 104    2
# 133    2
# 95     1
# 88     1
# 0      0
# 46     0
# 11     0
# 106    2
# 85     1
# 1      0
# 51     1
# 130    2
# 55     1
# 134    2
# 37     0
# 65     1
# 56     1
# Name: Species, dtype: int64

# %%
print(confusion_matrix(y_val, pred_1))
print(classification_report(y_val, pred_1))
# Out:
# [[13  0  0]
#  [ 0 16  2]
#  [ 0  4 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.80      0.89      0.84        18
#            2       0.83      0.71      0.77        14
#
#     accuracy                           0.87        45
#    macro avg       0.88      0.87      0.87        45
# weighted avg       0.87      0.87      0.87        45

# %% [markdown]
# ----

# %% [markdown]
# ## 4.모델링2 : hidden layer

# %% [markdown]
# ### (1) 모델1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 40 | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 3) | 27 | node, activation = 'softmax'  |

# %%
clear_session()

model = Sequential(
    [Input(shape = (nfeatures,)),
     Dense(8,activation='relu'),
     Dense(3,activation='softmax') # 다중분류에서 output layer는 softmax 이다
     ]
)

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 67 (268.00 B)
#  Trainable params: 67 (268.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss= 'sparse_categorical_crossentropy')
# 0,1,2,3 정수 라벨링인 경우 loss function 은 sparse_categorical_crossentropy
history = model.fit(x_train, y_train, epochs = 100,validation_split=0.2, verbose= False).history

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
# softmax는 결과들 중에서 가장 유력한 것을 선택해야 함
pred = pred.argmax(axis=1) # target범주들 중에서 가장 유력한 것을 선택

print(confusion_matrix(y_val, pred))
print(classification_report(y_val, pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[13  0  0]
#  [ 0 18  0]
#  [ 0  4 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.82      1.00      0.90        18
#            2       1.00      0.71      0.83        14
#
#     accuracy                           0.91        45
#    macro avg       0.94      0.90      0.91        45
# weighted avg       0.93      0.91      0.91        45

# %% [markdown]
# ### (2) 모델2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape |
# | ---- | ---- |
# | dense (Dense) | (None, 8) |
# | dense_1 (Dense) | (None, 8) |
# | dense_2 (Dense) | (None, 3) |

# %%
# 메모리 정리
clear_session()
# 모델 생성
model = Sequential(
    [Input(shape = (nfeatures,)),
     Dense(8,activation='relu'),
     Dense(8,activation='relu'),
     Dense(3,activation='softmax') # 다중분류에서 output layer는 softmax 이다
     ]
)

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 139 (556.00 B)
#  Trainable params: 139 (556.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile + 학습

# %%
# 0,1,2 정수 인코디시 loss function은 sparse_categorical_crossentropy 사용한다
model.compile(optimizer=Adam(learning_rate=0.1), loss= 'sparse_categorical_crossentropy')

# 0,1,2,3 정수 라벨링인 경우 loss function 은 sparse_categorical_crossentropy
history = model.fit(x_train, y_train, epochs = 50,validation_split=0.2, verbose= False).history

# %% [markdown]
# * 학습결과 그래프

# %%
# 학습결과 그래프
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %%
# 예측 + 평가
pred = model.predict(x_val)
# softmax는 결과들 중에서 가장 유력한 것을 선택해야 함
pred = pred.argmax(axis=1) # target범주들 중에서 가장 유력한 것을 선택

print(confusion_matrix(y_val, pred_1))
print(classification_report(y_val, pred_1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [[13  0  0]
#  [ 0 16  2]
#  [ 0  4 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.80      0.89      0.84        18
#            2       0.83      0.71      0.77        14
#
#     accuracy                           0.87        45
#    macro avg       0.88      0.87      0.87        45
# weighted avg       0.87      0.87      0.87        45

# %% [markdown]
# ### (3) 모델3

# %% [markdown]
# * 여러분이 원하는 형태로 설계를 해 봅시다.

# %% [markdown]
# * compile + 학습

# %% [markdown]
# * 학습결과 그래프

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %% [markdown]
# ## 5.참조 : y를 one-hot encoding 하여 모델링
#
# * y 가변수화 : to_categorical
# * 컴파일에서 loss = 'categorical_crossentropy'

# %%
from keras.utils import to_categorical

# %% [markdown]
# ### (1) y에 대한 가변수화

# %%
y

# %%
y_c = to_categorical(y.values, 3)

# %%
y_c[:5]

# %% [markdown]
# ### (2) 데이터 분할2 : train : val

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y_c, test_size = .3, random_state = 2022)

# %%
y_train.shape

# %% [markdown]
# ### (3) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (4) 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures

# %%
# 메모리 정리
clear_session()

# Sequential
model = Sequential([Input(shape = (nfeatures,)),
                    Dense(3, activation = 'softmax')])

# 모델요약
model.summary()

# %% [markdown]
# ### (5) compile + 학습
#
# * lr과 learning_rate은 같은 의미 입니다. 그러나 향후 버전에서는 lr이 제외될 예정이라고 합니다.
# * y를 one-hot encoding 했다면, loss fuction은 **categorical_crossentropy** 입니다.

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss='categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 100,
                    validation_split=0.2).history

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (6) 예측 및 평가
# * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
pred[:5]

# %% [markdown]
# * 행 별로 제일 큰 값을 찾아서 그에 맞게 숫자(0,1,2)로 변환 합시다.

# %%
# 5개 행만 살펴보면
np.argmax(pred[:5], axis = 1)

# %%
y_val

# %%
# 전체에 적용해서 변환합시다.
pred_1 = pred.argmax(axis=1)
pred_1

# %% [markdown]
# * 실제값 y_val도 원래 대로 돌려 놓습니다.

# %%
y_val[:5]

# %%
y_val_1 = y_val.argmax(axis=1)
y_val_1

# %%
print(confusion_matrix(y_val_1, pred_1))
print(classification_report(y_val_1, pred_1))
