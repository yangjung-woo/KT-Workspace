# %% [markdown]
# # Roboflow에서 가져온 데이터셋 사용해보기

# %% [markdown]
# ## 1.데이터셋

# %% [markdown]
# * 데이터셋 라이브러리 설치하기

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# * 데이터셋 라이브러리 불러오기
#
#     - **[링크](https://universe.roboflow.com/roboflow-58fyf/rock-paper-scissors-sxsw)**

# %%
from roboflow import Roboflow

# %% [markdown]
# * 데이터셋 설치하기

# %%
#############################################
## API key는 유저마다 다른 것이 정상!!
rf = Roboflow(api_key="DVzCkeTs5iatYrZbX4YZ")
###############################################
project = rf.workspace("bolamerah").project("bola-zvbsp")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to bola-4 in yolov11:: 100%|██████████| 814/814 [00:00<00:00, 5077.95it/s]

# %% [markdown]
# ## 2.모델링

# %% [markdown]
# * 모델링 라이브러리 설치하기

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 37.4 MB/s eta 0:00:00
# ...

# %%
#####################################
## 10/30 기준 해당 설정 필요
import os
os.environ['WANDB_MODE'] = 'disabled'
#####################################

# %% [markdown]
# * 모델링 라이브러리 불러오기

# %%
from ultralytics import YOLO, settings
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# * 데이터셋 경로 수정

# %%
settings
# Out:
# {'settings_version': '0.0.6',
#  'datasets_dir': '/content/',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': False,
#  'vscode_msg': True}

# %%
settings['datasets_dir'] = '/content/'
settings.update()
settings
# Out:
# {'settings_version': '0.0.6',
#  'datasets_dir': '/content/',
#  'weights_dir': 'weights',
#  'runs_dir': 'runs',
#  'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb',
#  'sync': True,
#  'api_key': '',
#  'openai_api_key': '',
#  'clearml': True,
#  'comet': True,
#  'dvc': True,
#  'hub': True,
#  'mlflow': True,
#  'neptune': True,
#  'raytune': True,
#  'tensorboard': True,
#  'wandb': False,
#  'vscode_msg': True}

# %% [markdown]
# ### 1) 모델 구조에 사전 학습 가중치도 가져와서 사용해보기

# %% [markdown]
# * 모델 구조 및 사전 학습 가중치 선택하기

# %%
model_transfer = YOLO('yolo11n.pt')
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 149MB/s]

# %% [markdown]
# * 모델 학습하기

# %%
results_train = model_transfer.train(model='/content/yolov11n.pt',
                                     data='/content/bola-4/data.yaml',
                                     epochs=1,
                                     seed=2024,
                                     pretrained=True,
                                     )
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# * 예측해보기

# %%
image_path = '/content/sample_data/basketball.jpg'

# %%
results_pred = model_transfer.predict(source=image_path,
                                      model = '/content/runs/detect/train2343/weights/best.pt',
                                      conf = 0.01,
                                      #iou=
                                      save=True,
                                      )
# Out:
# image 1/1 /content/sample_data/basketball.jpg: 448x640 (no detections), 12.5ms
# Speed: 2.7ms preprocess, 12.5ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/train23433
